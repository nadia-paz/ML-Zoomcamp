# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
# !python -V
# Out:
# Python 3.9.18

# %%
import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# '2.13.1'

# %%
model = keras.models.load_model('clothing_model.h5')

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import load_img 
from tensorflow.keras.applications.xception import preprocess_input

# %%
load_img('pants.jpg', target_size=(150, 150))
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
img = load_img('pants.jpg', target_size=(150, 150))

x = np.array(img)
X = np.array([x])

X = preprocess_input(X)

# %%
X.shape
# Out:
# (1, 150, 150, 3)

# %%
preds = model.predict(X)
preds
# Out:
# 1/1 [==============================] - 1s 695ms/step
# array([[-2.702204  , -4.701816  , -0.4534632 , -1.6223824 ,  1.9553057 ,
#         -0.80880034, -7.447846  , -2.1537106 , -2.356115  , -4.0100317 ]],
#       dtype=float32)

# %%
classes = [
    'dress',
    'hat',
    'longsleeve',
    'outwear',
    'pants',
    'shirt',
    'shoes',
    'shorts',
    'skirt',
    't-shirt'
]
dict(zip(classes, preds[0]))
# Out:
# {'dress': -2.702204,
#  'hat': -4.701816,
#  'longsleeve': -0.4534632,
#  'outwear': -1.6223824,
#  'pants': 1.9553057,
#  'shirt': -0.80880034,
#  'shoes': -7.447846,
#  'shorts': -2.1537106,
#  'skirt': -2.356115,
#  't-shirt': -4.0100317}
